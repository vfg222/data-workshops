# %% [markdown]
# # Ames Housing Prices (W09)
#
# In this workshop, you'll work with the classic **Ames Housing** dataset (the same dataset used in Kaggle's [House Prices competition](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques)). The goal is to predict each house's `SalePrice`.
#
# You are given:
# - `train.csv` with features **and** target `SalePrice`
# - `test.csv` with features only (no `SalePrice`)
# - `data_description.txt` with definitions for all columns
#
# Each row corresponds to one home sale in Ames, Iowa, with mixed numeric and categorical variables describing lot size, quality, age, neighborhood, basement/garage properties, and more. The `test.csv` file is what you would use when creating a Kaggle submission, so feel free to join the tutorial competition and submit your own predictions after the workshop!
#
# A key challenge in this dataset is careful preprocessing: many columns have missing values, and some `NA` values mean "not present" rather than truly missing data.
#
# Below are some suggested directions. Pick a level that fits you, or branch off with your own ideas. Happy coding!
#
# ##### **Beginner**
# - Start with basic orientation: `.head()`, `.info()`, `.describe()`, and check `train.shape` / `test.shape`.
# - Try converting a few key columns to the metric system (for example `LotArea`, `GrLivArea`, and `TotalBsmtSF` from square feet to square meters using `1 sq ft = 0.092903 sq m`) and see whether this makes your summaries easier to interpret.
# - Explore the target `SalePrice`:
#   - Plot a histogram of `SalePrice`.
#   - Is it skewed? Compare with `np.log1p(SalePrice)`.
# - Check missing values with `train.isna().sum().sort_values(ascending=False)`. Which columns have the most missing values?
# - Look at simple relationships:
#   - Correlation between numeric features and `SalePrice`.
#   - Average `SalePrice` by `Neighborhood` or `OverallQual`.
#
# ##### **Intermediate**
# - Build a baseline regression pipeline using [scikit-learn Pipelines](https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html):
#   - Numeric preprocessing (imputation, optional scaling).
#   - Categorical preprocessing ([one-hot encoding](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html)).
#   - A model such as [Ridge](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Ridge.html) or [RandomForestRegressor](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html).
# - Evaluate with validation split or cross-validation using RMSE (or RMSLE if you model log-prices).
# - Try target transformation: model `log1p(SalePrice)` and compare performance to modeling raw prices.
# - Add a few hand-crafted features, for example:
#   - `HouseAge = YrSold - YearBuilt`
#   - `RemodAge = YrSold - YearRemodAdd`
#   - `TotalSF = TotalBsmtSF + 1stFlrSF + 2ndFlrSF`
#
# ##### **Advanced**
# - Train a stronger tabular model such as [XGBoost](https://xgboost.readthedocs.io/en/stable/), [LightGBM](https://lightgbm.readthedocs.io/en/latest/), or [CatBoost](https://catboost.ai/docs/en/concepts/python-quickstart).
# - Use cross-validated hyperparameter tuning and compare model families rigorously.
# - Build an ensemble (e.g. blending linear + tree-based models) and measure whether it improves validation error.
# - Interpret the fitted model:
#   - Global feature importance.
#   - Local explanations using [SHAP](https://shap.readthedocs.io/en/latest/).
# - Produce final predictions for `test.csv` and export a Kaggle-style submission file with columns `Id` and `SalePrice`.

# %% [markdown]
# ## Code

# %%
import numpy as np
import pandas as pd

train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...
